# %% [markdown]
# <a href="https://colab.research.google.com/github/Bikram1407/Data_visualtization/blob/main/object_detection_yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.66 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.7/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="DqoRsIfBpHne1I6RqBPY")
project = rf.workspace("so-d4hcz").project("all_finalize")
version = project.version(3)
dataset = version.download("tensorflow")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.6 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to all_finalize--3 in tensorflow:: 100%|██████████| 6285/6285 [00:01<00:00, 4954.16it/s]

# %%
# !ls /content/all_finalize--3/train/
# Out:
# 100_jpg.rf.0a613f7b85bb2a37ba4f3b123ae85fb4.jpg
# 100_jpg.rf.7c6773ba98a126e4c5b048bd0ee990d1.jpg
# 100_jpg.rf.d1df942dfdd4eab421c923bcbcfb655a.jpg
# 102_jpg.rf.26c4bd9c443dcd93032d71f009983bcf.jpg
# 102_jpg.rf.4be039bfada92f1f81f625c0faa52e74.jpg
# 102_jpg.rf.4f925fd317ebd5874d920a46a7250332.jpg
# 103_jpg.rf.3d82e8b544baf43123536c94f4889d9f.jpg
# 103_jpg.rf.532854fa94b97af23830e3d1544d70d2.jpg
# 103_jpg.rf.6752be8dca7d448eb77021786d1d907c.jpg
# 106_jpg.rf.9284616005dc1785dcd8d171827cf032.jpg
# 106_jpg.rf.95c7f6d370f3897578c42e610b15f5d1.jpg
# 106_jpg.rf.b71acab165070492f0e15c86b46be221.jpg
# 107_jpg.rf.410003335f3805ed0bdb4a99c70cd2ae.jpg
# 107_jpg.rf.d3b267d18b53dac72315ec98e9be943f.jpg
# 107_jpg.rf.e25322fe66f52d08b8729883191e6d90.jpg
# 108_jpg.rf.43f13d405c62be8508d8ac3dd6629787.jpg
# 108_jpg.rf.54cdd2a3a8910932fa8dcb8e81275053.jpg
# 108_jpg.rf.902a7a8644f39ab5966d86082b9dae61.jpg
# 109_jpg.rf.41ebcb115cb75535e735f35887cb7db5.jpg
# 109_jpg.rf.9bf88fb405020f2a96ec711ef6a3974a.jpg
# ...

# %%
Image(filename=f'/content/all_finalize--3/train/103_jpg.rf.3d82e8b544baf43123536c94f4889d9f.jpg', width=600)

# %%
Image(filename=f'/content/all_finalize--3/train/Kitchen-100-_jpg.rf.03f2084b5c876163775a6aff75736c5e.jpg', width=600)

# %%
# !yolo task=detect mode=predict model=/content/datasets/all_finalize--3/train/ conf=0.25 source={dataset.location}/test/images save=True
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 803, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/model.py", line 23, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 142, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 299, in _load
#     weights = checks.check_file(weights)  # runs in all cases, not redundant with above call
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py", line 509, in check_file
#     raise FileNotFoundError(f"'{file}' does not exist")
# ...
